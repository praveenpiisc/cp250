# %%
from matplotlib import pyplot as plt
import numpy as np
import random
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge,Lasso
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
import pandas as pd

seed=123
random.seed(seed)
np.random.seed(seed)

# %% [markdown]
# # 1. Load the dataset
# lets's first load our dataset and print the header and footer rows

# %%
df = pd.read_csv('Singapore_BCA_2017_cleaned.csv')
df
# Out:
#            BuildingName                                   BuildingAddress  \
# 0     FUJI XEROX TOWERS                   80 ANSON ROAD, SINGAPORE 079907
# 1      CITY SQUARE MALL              180 KITCHENER ROAD, SINGAPORE 208539
# 2        REPUBLIC PLAZA                 9 RAFFLES PLACE, SINGAPORE 048619
# 3          CENTRAL MALL                 1 MAGAZINE ROAD, SINGAPORE 059567
# 4                ONE KM          11 TANJONG KATONG ROAD, SINGAPORE 437157
# ...                 ...                                               ...
# 1140  VANGUARD BUILDING                71 STAMFORD ROAD, SINGAPORE 178895
# 1141                NaN                                               NaN
# 1142        WILKIE EDGE                   8 WILKIE ROAD, SINGAPORE 228095
# 1143                NaN                                               NaN
# 1144         SWIBER@IBP  12 INTERNATIONAL BUSINESS PARK, SINGAPORE 609920
#
#                  BuildingType BuildingSize PublicSector  YearObtainedTOP_CSC  \
# 0             Office Building        Large           No               1989.0
# 1             Retail Building        Large           No               2009.0
# 2             Office Building        Large           No               1998.0
# 3             Office Building        Large           No               1999.0
# 4             Retail Building        Large           No               2014.0
# ...                       ...          ...          ...                  ...
# 1140          Office Building        Small           No               1901.0
# 1141  Educational Institution          NaN          NaN                  NaN
# 1142          Office Building        Large           No               2008.0
# 1143          Retail Building        Large          NaN                  NaN
# 1144          Office Building        Small           No               1992.0
#
#       GreenMarkYearofAward GreenMarkRating GreenMarkStatus  GrossFloorArea_M2  \
# 0                   2014.0        Platinum             Yes            48688.0
# 1                   2015.0        Platinum             Yes            65640.0
# 2                   2014.0        Platinum             Yes           102356.0
# 3                   2017.0        Platinum             Yes            15769.0
# 4                   2015.0            Gold             Yes            28938.0
# ...                    ...             ...             ...                ...
# 1140                   NaN   Not Certified              No             2900.0
# 1141                   NaN             NaN              No                NaN
# 1142                2016.0            Gold             Yes            29812.0
# 1143                   NaN             NaN              No                NaN
# 1144                   NaN   Not Certified              No            10841.0
#
#       ...  PercentageUsageOfLED  InstallationOfSolarPV  EUI2015_kWhM2Yr  \
# 0     ...                  50.0                      N            186.2
# 1     ...                  75.0                      Y            392.5
# 2     ...                   4.0                      N            244.9
# 3     ...                  50.0                      N            210.5
# 4     ...                  31.0                      N            466.6
# ...   ...                   ...                    ...              ...
# 1140  ...                   0.0                      N            289.3
# 1141  ...                   NaN                    NaN            171.7
# 1142  ...                  20.0                      N            271.6
# 1143  ...                   NaN                    NaN            124.5
# 1144  ...                   0.0                      N            195.2
#
#      EUI2016_kWhM2Yr  EUI2017_kWhM2Yr  EUIPerformanceComparedToPreviousYear  \
# 0              181.3            169.3                              Improved
# 1              384.9            382.2                              Improved
# 2              242.7            212.4                              Improved
# 3              197.4            202.8                              Worsened
# 4              462.7            430.7                              Improved
# ...              ...              ...                                   ...
# 1140           323.9            263.1                              Improved
# 1141           150.0            148.7                              Improved
# 1142           268.0            261.6                              Improved
# 1143           128.5            112.2                              Improved
# 1144           189.7            137.8                              Improved
#
#       Benchmarking_EUI_Quartile  VoluntaryDisclosure BuildingAge  \
# 0                  2nd Quartile                    Y        29.0
# 1                  2nd Quartile                    Y         9.0
# 2                  3rd Quartile                    Y        20.0
# 3                  3rd Quartile                    Y        19.0
# 4                  3rd Quartile                    Y         4.0
# ...                         ...                  ...         ...
# 1140            Bottom Quartile                    Y       117.0
# 1141                        NaN                  NaN         NaN
# 1142            Bottom Quartile                    Y        10.0
# 1143               Top Quartile                    N         NaN
# 1144               2nd Quartile                    Y        26.0
#
#       TotalEnergy2017
# 0           8242878.4
# 1          25087608.0
# 2          21740414.4
# 3           3197953.2
# 4          12463596.6
# ...               ...
# 1140         762990.0
# 1141              NaN
# 1142        7798819.2
# 1143              NaN
# 1144        1493889.8
#
# [1145 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1145 entries, 0 to 1144
# Data columns (total 27 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   BuildingName                                    643 non-null    object
#  1   BuildingAddress                                 802 non-null    object
#  2   BuildingType                                    1145 non-null   object
#  3   BuildingSize                                    957 non-null    object
#  4   PublicSector                                    802 non-null    object
#  5   YearObtainedTOP_CSC                             802 non-null    float64
#  6   GreenMarkYearofAward                            208 non-null    float64
#  7   GreenMarkRating                                 802 non-null    object
#  8   GreenMarkStatus                                 1145 non-null   object
#  9   GrossFloorArea_M2                               802 non-null    float64
#  10  PercentageOfAirconditionedFloorArea             802 non-null    float64
#  11  AverageMonthlyBuildingOccupancyRate_percentage  802 non-null    float64
#  12  NumberOfHotelRooms                              258 non-null    float64
#  13  TypeOfAirconditioningSystem                     802 non-null    object
#  14  AgeOfNewestChiller_Airconditioner               783 non-null    float64
#  15  CentralisedAirconditioningPlantEfficiency_kWRT  231 non-null    float64
#  16  YearOfLastChillerPlantAuditHealthCheck          190 non-null    float64
#  17  PercentageUsageOfLED                            802 non-null    float64
#  18  InstallationOfSolarPV                           802 non-null    object
#  19  EUI2015_kWhM2Yr                                 1145 non-null   float64
#  20  EUI2016_kWhM2Yr                                 1145 non-null   float64
#  21  EUI2017_kWhM2Yr                                 1145 non-null   float64
#  22  EUIPerformanceComparedToPreviousYear            1145 non-null   object
#  23  Benchmarking_EUI_Quartile                       1015 non-null   object
#  24  VoluntaryDisclosure                             1015 non-null   object
#  25  BuildingAge                                     802 non-null    float64
#  26  TotalEnergy2017                                 802 non-null    float64
# dtypes: float64(15), object(12)
# memory usage: 241.7+ KB

# %%
df.describe()
# Out:
#        YearObtainedTOP_CSC  GreenMarkYearofAward  GrossFloorArea_M2  \
# count           802.000000            208.000000         802.000000
# mean           1994.442643           2013.961538       22431.937656
# std              17.706790              2.331979       43717.330939
# min            1900.000000           2007.000000         107.000000
# 25%            1986.000000           2013.000000        2027.500000
# 50%            1997.000000           2014.000000        8718.500000
# 75%            2008.000000           2016.000000       25852.250000
# max            2017.000000           2017.000000      581511.000000
#
#        PercentageOfAirconditionedFloorArea  \
# count                           802.000000
# mean                             78.448878
# std                              20.761183
# min                               0.000000
# 25%                              70.000000
# 50%                              83.000000
# 75%                              94.000000
# max                             100.000000
#
#        AverageMonthlyBuildingOccupancyRate_percentage  NumberOfHotelRooms  \
# count                                      802.000000          258.000000
# mean                                        85.304239          222.639535
# std                                         17.014783          677.918373
# min                                          1.000000            1.000000
# 25%                                         80.000000           33.000000
# 50%                                         90.000000           73.500000
# 75%                                        100.000000          240.000000
# max                                        100.000000         9999.000000
#
#        AgeOfNewestChiller_Airconditioner  \
# count                         783.000000
# mean                            7.336462
# std                             6.732357
# min                             0.000000
# 25%                             3.000000
# 50%                             5.000000
# 75%                            10.000000
# max                            40.000000
#
#        CentralisedAirconditioningPlantEfficiency_kWRT  \
# count                                      231.000000
# mean                                         0.770390
# std                                          0.268866
# min                                          0.500000
# 25%                                          0.630000
# 50%                                          0.680000
# 75%                                          0.830000
# max                                          3.340000
#
#        YearOfLastChillerPlantAuditHealthCheck  PercentageUsageOfLED  \
# count                              190.000000            802.000000
# mean                              2014.763158             28.523691
# std                                  2.279820             35.660069
# min                               2002.000000              0.000000
# 25%                               2013.250000              0.000000
# 50%                               2015.000000             10.000000
# 75%                               2016.000000             55.000000
# max                               2017.000000            100.000000
#
#        EUI2015_kWhM2Yr  EUI2016_kWhM2Yr  EUI2017_kWhM2Yr  BuildingAge  \
# count      1145.000000      1145.000000      1145.000000   802.000000
# mean        270.797817       274.231790       266.577642    23.557357
# std         197.250655       192.460306       185.580283    17.706790
# min         -13.000000        10.700000         9.300000     1.000000
# 25%         157.700000       157.300000       153.500000    10.000000
# 50%         231.700000       234.700000       223.000000    21.000000
# 75%         333.100000       339.400000       328.900000    32.000000
# max        2882.500000      2676.600000      2602.400000   118.000000
#
#        TotalEnergy2017
# count     8.020000e+02
# mean      6.308383e+06
# std       1.404079e+07
# min       6.086400e+03
# 25%       3.785570e+05
# 50%       1.985386e+06
# 75%       6.836125e+06
# max       1.750930e+08

# %% [markdown]
# # 2. Extract only the Office bulidings

# %%
dfn = df[df.BuildingType == 'Office Building']
dfn
# Out:
#             BuildingName                                   BuildingAddress  \
# 0      FUJI XEROX TOWERS                   80 ANSON ROAD, SINGAPORE 079907
# 2         REPUBLIC PLAZA                 9 RAFFLES PLACE, SINGAPORE 048619
# 3           CENTRAL MALL                 1 MAGAZINE ROAD, SINGAPORE 059567
# 6     GREATWOOD BUILDING             43 CARPENTER STREET, SINGAPORE 059922
# 7          TIALOC CENTRE           731 NORTH BRIDGE ROAD, SINGAPORE 198699
# ...                  ...                                               ...
# 1137  BISHAN SPORTS HALL              5 BISHAN STREET 14, SINGAPORE 579783
# 1138                 NaN                                               NaN
# 1140   VANGUARD BUILDING                71 STAMFORD ROAD, SINGAPORE 178895
# 1142         WILKIE EDGE                   8 WILKIE ROAD, SINGAPORE 228095
# 1144          SWIBER@IBP  12 INTERNATIONAL BUSINESS PARK, SINGAPORE 609920
#
#          BuildingType BuildingSize PublicSector  YearObtainedTOP_CSC  \
# 0     Office Building        Large           No               1989.0
# 2     Office Building        Large           No               1998.0
# 3     Office Building        Large           No               1999.0
# 6     Office Building        Small           No               1984.0
# 7     Office Building        Small           No               2003.0
# ...               ...          ...          ...                  ...
# 1137  Office Building        Small          Yes               1998.0
# 1138  Office Building        Small          NaN                  NaN
# 1140  Office Building        Small           No               1901.0
# 1142  Office Building        Large           No               2008.0
# 1144  Office Building        Small           No               1992.0
#
#       GreenMarkYearofAward GreenMarkRating GreenMarkStatus  GrossFloorArea_M2  \
# 0                   2014.0        Platinum             Yes            48688.0
# 2                   2014.0        Platinum             Yes           102356.0
# 3                   2017.0        Platinum             Yes            15769.0
# 6                      NaN   Not Certified              No              913.0
# 7                      NaN   Not Certified              No              385.0
# ...                    ...             ...             ...                ...
# 1137                   NaN   Not Certified              No             2375.0
# 1138                   NaN             NaN              No                NaN
# 1140                   NaN   Not Certified              No             2900.0
# 1142                2016.0            Gold             Yes            29812.0
# 1144                   NaN   Not Certified              No            10841.0
#
#       ...  PercentageUsageOfLED  InstallationOfSolarPV  EUI2015_kWhM2Yr  \
# 0     ...                  50.0                      N            186.2
# 2     ...                   4.0                      N            244.9
# 3     ...                  50.0                      N            210.5
# 6     ...                   0.0                      N            275.8
# 7     ...                   0.0                      N            184.1
# ...   ...                   ...                    ...              ...
# 1137  ...                   0.0                      N            581.5
# 1138  ...                   NaN                    NaN            182.3
# 1140  ...                   0.0                      N            289.3
# 1142  ...                  20.0                      N            271.6
# 1144  ...                   0.0                      N            195.2
#
#      EUI2016_kWhM2Yr  EUI2017_kWhM2Yr  EUIPerformanceComparedToPreviousYear  \
# 0              181.3            169.3                              Improved
# 2              242.7            212.4                              Improved
# 3              197.4            202.8                              Worsened
# 6              247.5            222.5                              Improved
# 7              200.7            196.9                              Improved
# ...              ...              ...                                   ...
# 1137           539.8            552.1                              Worsened
# 1138           215.6            239.2                              Worsened
# 1140           323.9            263.1                              Improved
# 1142           268.0            261.6                              Improved
# 1144           189.7            137.8                              Improved
#
#       Benchmarking_EUI_Quartile  VoluntaryDisclosure BuildingAge  \
# 0                  2nd Quartile                    Y        29.0
# 2                  3rd Quartile                    Y        20.0
# 3                  3rd Quartile                    Y        19.0
# 6                  3rd Quartile                    Y        34.0
# 7                  3rd Quartile                    Y        15.0
# ...                         ...                  ...         ...
# 1137            Bottom Quartile                    Y        20.0
# 1138               3rd Quartile                    N         NaN
# 1140            Bottom Quartile                    Y       117.0
# 1142            Bottom Quartile                    Y        10.0
# 1144               2nd Quartile                    Y        26.0
#
#       TotalEnergy2017
# 0           8242878.4
# 2          21740414.4
# 3           3197953.2
# 6            203142.5
# 7             75806.5
# ...               ...
# 1137        1311237.5
# 1138              NaN
# 1140         762990.0
# 1142        7798819.2
# 1144        1493889.8
#
# [482 rows x 27 columns]

# %%
dfn.describe()
# Out:
#        YearObtainedTOP_CSC  GreenMarkYearofAward  GrossFloorArea_M2  \
# count           387.000000            111.000000         387.000000
# mean           1993.219638           2013.891892       23285.545220
# std              17.431757              2.221185       33879.106876
# min            1900.000000           2008.000000         272.000000
# 25%            1986.000000           2013.000000        3347.500000
# 50%            1997.000000           2014.000000       10917.000000
# 75%            2003.500000           2016.000000       28114.000000
# max            2017.000000           2017.000000      309099.000000
#
#        PercentageOfAirconditionedFloorArea  \
# count                           387.000000
# mean                             77.937984
# std                              20.689069
# min                               0.000000
# 25%                              71.000000
# 50%                              81.000000
# 75%                              92.500000
# max                             100.000000
#
#        AverageMonthlyBuildingOccupancyRate_percentage  NumberOfHotelRooms  \
# count                                      387.000000           11.000000
# mean                                        89.777778          108.000000
# std                                         15.092366          116.460294
# min                                          5.000000            1.000000
# 25%                                         85.000000            5.500000
# 50%                                         95.000000           46.000000
# 75%                                        100.000000          201.000000
# max                                        100.000000          305.000000
#
#        AgeOfNewestChiller_Airconditioner  \
# count                         377.000000
# mean                            8.189523
# std                             7.122049
# min                             0.000000
# 25%                             3.000000
# 50%                             6.000000
# 75%                            11.000000
# max                            40.000000
#
#        CentralisedAirconditioningPlantEfficiency_kWRT  \
# count                                      121.000000
# mean                                         0.765868
# std                                          0.210996
# min                                          0.540000
# 25%                                          0.630000
# 50%                                          0.680000
# 75%                                          0.870000
# max                                          1.580000
#
#        YearOfLastChillerPlantAuditHealthCheck  PercentageUsageOfLED  \
# count                              100.000000            387.000000
# mean                              2014.510000             18.397933
# std                                  2.576094             28.895771
# min                               2002.000000              0.000000
# 25%                               2013.000000              0.000000
# 50%                               2015.000000              2.000000
# 75%                               2016.000000             25.000000
# max                               2017.000000            100.000000
#
#        EUI2015_kWhM2Yr  EUI2016_kWhM2Yr  EUI2017_kWhM2Yr  BuildingAge  \
# count       482.000000       482.000000       482.000000   387.000000
# mean        238.617842       241.809129       232.843983    24.780362
# std         192.881609       193.987344       183.205812    17.431757
# min         -13.000000        10.700000         9.300000     1.000000
# 25%         145.625000       142.700000       138.850000    14.500000
# 50%         200.600000       200.500000       189.750000    21.000000
# 75%         272.050000       270.750000       255.825000    32.000000
# max        1867.400000      1785.500000      1667.700000   118.000000
#
#        TotalEnergy2017
# count     3.870000e+02
# mean      5.539789e+06
# std       1.045762e+07
# min       1.879520e+04
# 25%       5.842569e+05
# 50%       2.152212e+06
# 75%       6.588804e+06
# max       1.172756e+08

# %% [markdown]
# # 3. Data cleaning

# %%
columns_to_include = ['BuildingType',
                      'BuildingSize',
                      'GrossFloorArea_M2',
                      'PercentageOfAirconditionedFloorArea',
                      'PercentageUsageOfLED',
                      'BuildingAge',
                      'AverageMonthlyBuildingOccupancyRate_percentage',
                      'TotalEnergy2017']
dfn = dfn[columns_to_include]

dfn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 482 entries, 0 to 1144
# Data columns (total 8 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   BuildingType                                    482 non-null    object
#  1   BuildingSize                                    482 non-null    object
#  2   GrossFloorArea_M2                               387 non-null    float64
#  3   PercentageOfAirconditionedFloorArea             387 non-null    float64
#  4   PercentageUsageOfLED                            387 non-null    float64
#  5   BuildingAge                                     387 non-null    float64
#  6   AverageMonthlyBuildingOccupancyRate_percentage  387 non-null    float64
#  7   TotalEnergy2017                                 387 non-null    float64
# dtypes: float64(6), object(2)
# memory usage: 33.9+ KB

# %%
dfn['AirconFA'] = round(dfn['GrossFloorArea_M2'] * dfn['PercentageOfAirconditionedFloorArea'] / 100)
dfn['NonAirconFA'] = dfn['GrossFloorArea_M2'] - dfn['AirconFA']
dfn
# Out:
# C:\Users\praveenp1\AppData\Local\Temp\3\ipykernel_12924\4075213146.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfn['AirconFA'] = round(dfn['GrossFloorArea_M2'] * dfn['PercentageOfAirconditionedFloorArea'] / 100)
# C:\Users\praveenp1\AppData\Local\Temp\3\ipykernel_12924\4075213146.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfn['NonAirconFA'] = dfn['GrossFloorArea_M2'] - dfn['AirconFA']
#          BuildingType BuildingSize  GrossFloorArea_M2  \
# 0     Office Building        Large            48688.0
# 2     Office Building        Large           102356.0
# 3     Office Building        Large            15769.0
# 6     Office Building        Small              913.0
# 7     Office Building        Small              385.0
# ...               ...          ...                ...
# 1137  Office Building        Small             2375.0
# 1138  Office Building        Small                NaN
# 1140  Office Building        Small             2900.0
# 1142  Office Building        Large            29812.0
# 1144  Office Building        Small            10841.0
#
#       PercentageOfAirconditionedFloorArea  PercentageUsageOfLED  BuildingAge  \
# 0                                    69.0                  50.0         29.0
# 2                                    80.0                   4.0         20.0
# 3                                    90.0                  50.0         19.0
# 6                                   100.0                   0.0         34.0
# 7                                    94.0                   0.0         15.0
# ...                                   ...                   ...          ...
# 1137                                 17.0                   0.0         20.0
# 1138                                  NaN                   NaN          NaN
# 1140                                 79.0                   0.0        117.0
# 1142                                 66.0                  20.0         10.0
# 1144                                 81.0                   0.0         26.0
#
#       AverageMonthlyBuildingOccupancyRate_percentage  TotalEnergy2017  \
# 0                                               96.0        8242878.4
# 2                                               80.0       21740414.4
# 3                                               93.0        3197953.2
# 6                                              100.0         203142.5
# 7                                              100.0          75806.5
# ...                                              ...              ...
# 1137                                            80.0        1311237.5
# 1138                                             NaN              NaN
# 1140                                           100.0         762990.0
# 1142                                            99.0        7798819.2
# 1144                                           100.0        1493889.8
#
#       AirconFA  NonAirconFA
# 0      33595.0      15093.0
# 2      81885.0      20471.0
# 3      14192.0       1577.0
# 6        913.0          0.0
# 7        362.0         23.0
# ...        ...          ...
# 1137     404.0       1971.0
# 1138       NaN          NaN
# 1140    2291.0        609.0
# 1142   19676.0      10136.0
# 1144    8781.0       2060.0
#
# [482 rows x 10 columns]

# %%
dfn = dfn.dropna()
dfn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 387 entries, 0 to 1144
# Data columns (total 10 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   BuildingType                                    387 non-null    object
#  1   BuildingSize                                    387 non-null    object
#  2   GrossFloorArea_M2                               387 non-null    float64
#  3   PercentageOfAirconditionedFloorArea             387 non-null    float64
#  4   PercentageUsageOfLED                            387 non-null    float64
#  5   BuildingAge                                     387 non-null    float64
#  6   AverageMonthlyBuildingOccupancyRate_percentage  387 non-null    float64
#  7   TotalEnergy2017                                 387 non-null    float64
#  8   AirconFA                                        387 non-null    float64
#  9   NonAirconFA                                     387 non-null    float64
# dtypes: float64(8), object(2)
# memory usage: 33.3+ KB

# %% [markdown]
# # 4. Exploratory Data Analysis

# %%
dfn['TotalEnergy2017'].plot()
plt.show()

# %% [markdown]
# ## Plot correlations

# %%
import seaborn as sb 
dataplot = sb.heatmap(dfn.corr(), cmap="YlGnBu", annot=True) 
plt.show()
# Out:
# C:\Users\praveenp1\AppData\Local\Temp\3\ipykernel_12924\1061781310.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataplot = sb.heatmap(dfn.corr(), cmap="YlGnBu", annot=True)

# %% [markdown]
# ## Scatter Plot

# %%
sb.scatterplot(x='TotalEnergy2017', y='GrossFloorArea_M2', data=df, hue='BuildingSize')
plt.show()

# %% [markdown]
# # 5. Model development

# %%
def prepare_dataset(df):
    y_col = 'TotalEnergy2017'
    x_cols = ['AirconFA', 'NonAirconFA', 'BuildingAge']

    X = np.array(df[x_cols])
    y = np.array(df[y_col])
    return X, y

# %% [markdown]
# ## 5.1 OLS Regression

# %%
import statsmodels.api as sm

def fit_ols(X_train, y_train):
    model = sm.OLS(y_train, X_train).fit()
    return model

# %%
X, y = prepare_dataset(dfn)
X_train,X_test,y_train,y_test = train_test_split (X,y,test_size=0.2,random_state=3)
ols = fit_ols(X_train, y_train)
mS=ols.params

# %% [markdown]
# ### Prediction against Test - OLS

# %%
y_predS = ols.predict(X_test)
rmseS=np.sqrt(np.mean((y_test-y_predS)**2))
print('RMSE Error OLS',rmseS)

plt.figure(figsize=(12,6))
plt.plot(y_test,label ='Y Test')
plt.plot(y_predS,label = 'Y Pred Stats')
plt.xlabel('BuildingNo')
plt.ylabel('TotalEnergyUsage')

plt.legend()
# Out:
# RMSE Error OLS 3761912.301997066

# %% [markdown]
# ## 5.2 Linear Regression

# %%
def fit_linreg(X_train, y_train):
    reg= LinearRegression().fit(X_train,y_train)
    return reg

# %%
reg= fit_linreg(X_train, y_train)
R=reg.score(X_train,y_train)
m=reg.coef_
yz = reg.intercept_
print("model",m,yz,R)
len(X)
# Out:
# model [   241.53265967    248.6567017  -21252.61531353] 487037.34072424006 0.5828834399553536
# 387

# %% [markdown]
# ### Prediction against Test -Linear Regression

# %%
y_pred = reg.predict(X_test)
rmse=np.sqrt(np.mean((y_test-y_pred)**2))
print('RMSE ERROR Lin.Reg',rmse)

plt.figure(figsize=(12,6))
plt.plot(y_test,label ='Y Test')
plt.plot(y_pred,label = 'Y Prediction')
plt.xlabel('BuildingNo')
plt.ylabel('TotalEnergyUsage')

plt.legend()
# Out:
# RMSE ERROR Lin.Reg 3748622.771232097

# %% [markdown]
# ## 5.3 Linear Regression with Ridge Regularisation

# %%
def fit_linridge(X_train, y_train,alpha):
    reg= Ridge().fit(X_train,y_train,alpha)
    return reg

# %%
# regl2 = Ridge(alpha=0.9)
# regl2.fit(X_train, y_train)
alpha = 0.9
regl2= fit_linridge(X_train,y_train,alpha)

R2l2=regl2.score(X_train,y_train)
mr=regl2.coef_
yzr = regl2.intercept_

print("Ridge model",mr,yzr,R2l2)
# Out:
# Ridge model [   241.53268648    248.65672316 -21252.36600934] 487030.48274359386 0.5828834399551928

# %% [markdown]
# ### Prediction against Test - Ridge Regression

# %%
y_predr = regl2.predict(X_test)
rmser=np.sqrt(np.mean((y_test-y_predr)**2))
print('RMSE ERROR Rridge Reg',rmser)

plt.figure(figsize=(12,6))
plt.plot(y_test,label ='Y Test')
plt.plot(y_predr,label = 'Y Prediction')
plt.xlabel('BuildingNo')
plt.ylabel('TotalEnergyUsage')
# Out:
# RMSE ERROR Rridge Reg 3748622.821275289
# Text(0, 0.5, 'TotalEnergyUsage')

# %% [markdown]
# ## 5.4 Linear Regression with Lasso Regularisation

# %%
def fit_linlasso(X_train, y_train,alpha):
    reg= Lasso().fit(X_train,y_train,alpha)
    return reg

# %%
# regl1 = Lasso(alpha=0.9)
# regl1.fit(X_train, y_train)
alpha =0.9
regl1 = fit_linlasso(X_train, y_train,alpha)
R2l1=regl1.score(X_train,y_train)
ml=regl1.coef_
yzl = regl1.intercept_ 
print("Lasso model",ml,yzl,R2l1)
# Out:
# Lasso model [   241.53266002    248.65670196 -21252.61205167] 487037.25102745835 0.5828834399553537

# %% [markdown]
# ### Prediction against Test - Lasso Regression

# %%
y_predl = regl1.predict(X_test)
rmsel=np.sqrt(np.mean((y_test-y_predl)**2))
print('RMSE ERROR Rridge Reg',rmsel)

plt.figure(figsize=(12,6))
plt.plot(y_test,label ='Y Test')
plt.plot(y_predl,label = 'Y Prediction')
plt.xlabel('BuildingNo')
plt.ylabel('TotalEnergyUsage')

plt.legend()
# Out:
# RMSE ERROR Rridge Reg 3748622.7718189317

# %% [markdown]
# ## 5.5 Model Comparison - OLS, Lin Reg, Ridge and Lasso

# %% [markdown]
# ### Co-efficients

# %%
print('Coefficients')
print('LR',m)
print('Lasso',ml)
print ('Ridge',mr)
print('OLS SM',mS[:])
print('Intercepts')
print(yz,yzl,yzr)
# Out:
# Coefficients
# LR [   241.53265967    248.6567017  -21252.61531353]
# Lasso [   241.53266002    248.65670196 -21252.61205167]
# Ridge [   241.53268648    248.65672316 -21252.36600934]
# OLS SM [   245.05793989    252.63528825 -10113.0625249 ]
# Intercepts
# 487037.34072424006 487037.25102745835 487030.48274359386

# %% [markdown]
# ### RMSE Testing Error

# %%
print('LR:',rmse,'Lasso:',rmsel,'Ridge:',rmser,'OLS:',rmseS)
# Out:
# LR: 3748622.771232097 Lasso: 3748622.7718189317 Ridge: 3748622.821275289 OLS: 3761912.301997066

# %% [markdown]
# ## 5.6 Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor
def fit_dtreg(X_train, y_train, max_depth):
    reg = DecisionTreeRegressor(max_depth=max_depth)
    reg.fit(X_train, y_train)
    return reg

# %% [markdown]
# ###  Decision Tree with two depths

# %%
# regr_1 = DecisionTreeRegressor(max_depth=2)
# regr_2 = DecisionTreeRegressor(max_depth=5)
# regr_1.fit(X_train, y_train)
# regr_2.fit(X_train, y_train)

regr_1 = fit_dtreg(X_train, y_train,max_depth=2)
regr_2 = fit_dtreg(X_train, y_train,max_depth=5)
# regr_1.fit(X_train, y_train)
# regr_2.fit(X_train, y_train)

# %% [markdown]
# ### Prediction results

# %%
ypred_1 = regr_1.predict(X_test)
ypred_2 = regr_2.predict(X_test)
rmsedr1=np.sqrt(np.mean((y_test-ypred_1)**2))
rmsedr2=np.sqrt(np.mean((y_test-ypred_2)**2))

print('RMSE ERROR Dec Tree Reg',rmsedr1,rmsedr2)
# Out:
# RMSE ERROR Dec Tree Reg 10533201.952544754 14061817.302792806

# %%
plt.figure(figsize=(12,6))
plt.plot(y_test,label ='Y Test')
plt.plot(ypred_1,label = 'Y Pred Stats1 depth2')
plt.plot(ypred_2,label = 'Y Pred Stats2 depth 5')
plt.xlabel('BuildingNo')
plt.ylabel('TotalEnergyUsage')

plt.legend()

# %% [markdown]
# ### Decision Trees

# %%
from sklearn.tree import export_graphviz  
from sklearn import tree
# export the decision tree to a tree.dot file 
# for visualizing the plot easily anywhere 
export_graphviz(regr_2, out_file ='tree.dot')  
tree.plot_tree(regr_1)
# Out:
# [Text(0.5, 0.8333333333333334, 'x[0] <= 104371.5\nsquared_error = 118480972485824.73\nsamples = 309\nvalue = 5494756.409'),
#  Text(0.25, 0.5, 'x[0] <= 27014.5\nsquared_error = 34247174166399.63\nsamples = 304\nvalue = 4495468.865'),
#  Text(0.125, 0.16666666666666666, 'squared_error = 9840057237450.3\nsamples = 247\nvalue = 2500325.212'),
#  Text(0.375, 0.16666666666666666, 'squared_error = 48015300259916.69\nsamples = 57\nvalue = 13141091.365'),
#  Text(0.75, 0.5, 'x[2] <= 14.0\nsquared_error = 1487808029826685.0\nsamples = 5\nvalue = 66251439.04'),
#  Text(0.625, 0.16666666666666666, 'squared_error = 1100529595266395.0\nsamples = 3\nvalue = 89252916.2'),
#  Text(0.875, 0.16666666666666666, 'squared_error = 84720863384599.25\nsamples = 2\nvalue = 31749223.3')]

# %%
tree.plot_tree(regr_2)
# Out:
# [Text(0.65, 0.9166666666666666, 'x[0] <= 104371.5\nsquared_error = 118480972485824.73\nsamples = 309\nvalue = 5494756.409'),
#  Text(0.4, 0.75, 'x[0] <= 27014.5\nsquared_error = 34247174166399.63\nsamples = 304\nvalue = 4495468.865'),
#  Text(0.2, 0.5833333333333334, 'x[0] <= 7977.5\nsquared_error = 9840057237450.293\nsamples = 247\nvalue = 2500325.212'),
#  Text(0.1, 0.4166666666666667, 'x[0] <= 4243.0\nsquared_error = 1225469308184.275\nsamples = 145\nvalue = 878886.082'),
#  Text(0.05, 0.25, 'x[1] <= 1119.0\nsquared_error = 260833300183.094\nsamples = 119\nvalue = 574233.75'),
#  Text(0.025, 0.08333333333333333, 'squared_error = 173959629460.089\nsamples = 87\nvalue = 429774.574'),
#  Text(0.075, 0.08333333333333333, 'squared_error = 286033688198.009\nsamples = 32\nvalue = 966982.137'),
#  Text(0.15, 0.25, 'x[1] <= 3638.0\nsquared_error = 3271467457150.492\nsamples = 26\nvalue = 2273256.369'),
#  Text(0.125, 0.08333333333333333, 'squared_error = 1365733236902.411\nsamples = 24\nvalue = 1866757.983'),
#  Text(0.175, 0.08333333333333333, 'squared_error = 362691813120.984\nsamples = 2\nvalue = 7151237.0'),
#  Text(0.3, 0.4166666666666667, 'x[0] <= 17767.0\nsquared_error = 13035924002828.73\nsamples = 102\nvalue = 4805312.21'),
#  Text(0.25, 0.25, 'x[1] <= 3202.0\nsquared_error = 10553457301566.46\nsamples = 73\nvalue = 3935083.366'),
#  Text(0.225, 0.08333333333333333, 'squared_error = 4623371218923.926\nsamples = 50\nvalue = 3462295.444'),
#  Text(0.275, 0.08333333333333333, 'squared_error = 21902644949675.79\nsamples = 23\nvalue = 4962883.196'),
#  Text(0.35, 0.25, 'x[1] <= 241.0\nsquared_error = 12579965981373.477\nsamples = 29\nvalue = 6995888.266'),
#  Text(0.325, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 19949506.5'),
#  Text(0.375, 0.08333333333333333, 'squared_error = 6822502348594.742\nsamples = 28\nvalue = 6533259.043'),
#  Text(0.6, 0.5833333333333334, 'x[0] <= 61429.5\nsquared_error = 48015300259916.59\nsamples = 57\nvalue = 13141091.365'),
#  Text(0.5, 0.4166666666666667, 'x[1] <= 22219.5\nsquared_error = 17641602536193.594\nsamples = 44\nvalue = 10364431.955'),
#  Text(0.45, 0.25, 'x[2] <= 6.5\nsquared_error = 11570326099315.623\nsamples = 39\nvalue = 9560919.138'),
#  Text(0.425, 0.08333333333333333, 'squared_error = 18927332729540.5\nsamples = 6\nvalue = 12751964.983'),
#  Text(0.475, 0.08333333333333333, 'squared_error = 8044654536911.812\nsamples = 33\nvalue = 8980728.985'),
#  Text(0.55, 0.25, 'x[2] <= 18.5\nsquared_error = 20681320221095.246\nsamples = 5\nvalue = 16631831.92'),
#  Text(0.525, 0.08333333333333333, 'squared_error = 8942845329726.938\nsamples = 2\nvalue = 21529213.75'),
#  Text(0.575, 0.08333333333333333, 'squared_error = 1857693716658.094\nsamples = 3\nvalue = 13366910.7'),
#  Text(0.7, 0.4166666666666667, 'x[1] <= 20632.0\nsquared_error = 36402771828991.51\nsamples = 13\nvalue = 22539015.523'),
#  Text(0.65, 0.25, 'x[2] <= 21.0\nsquared_error = 7916378383310.375\nsamples = 6\nvalue = 18002790.367'),
#  Text(0.625, 0.08333333333333333, 'squared_error = 93070389535.375\nsamples = 2\nvalue = 21435340.0'),
#  Text(0.675, 0.08333333333333333, 'squared_error = 2991234641225.438\nsamples = 4\nvalue = 16286515.55'),
#  Text(0.75, 0.25, 'x[0] <= 72544.5\nsquared_error = 28063916900134.125\nsamples = 7\nvalue = 26427208.514'),
#  Text(0.725, 0.08333333333333333, 'squared_error = 2144006977351.875\nsamples = 2\nvalue = 19681402.8'),
#  Text(0.775, 0.08333333333333333, 'squared_error = 12948579817708.623\nsamples = 5\nvalue = 29125530.8'),
#  Text(0.9, 0.75, 'x[2] <= 14.0\nsquared_error = 1487808029826685.0\nsamples = 5\nvalue = 66251439.04'),
#  Text(0.85, 0.5833333333333334, 'x[0] <= 212399.5\nsquared_error = 1100529595266392.1\nsamples = 3\nvalue = 89252916.2'),
#  Text(0.825, 0.4166666666666667, 'x[1] <= 32108.0\nsquared_error = 22316318665030.0\nsamples = 2\nvalue = 112551543.3'),
#  Text(0.8, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 117275558.4'),
#  Text(0.85, 0.25, 'squared_error = -4.0\nsamples = 1\nvalue = 107827528.2'),
#  Text(0.875, 0.4166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 42655662.0'),
#  Text(0.95, 0.5833333333333334, 'x[0] <= 127397.0\nsquared_error = 84720863384599.25\nsamples = 2\nvalue = 31749223.3'),
#  Text(0.925, 0.4166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 40953617.0'),
#  Text(0.975, 0.4166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 22544829.6')]

# %% [markdown]
# # 5.7 Support Vector Regression

# %%
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
def fit_svreg(X_train, y_train, kernel,C):
    reg = SVR(kernel=kernel,C=C)
    reg.fit(X_train, y_train)
    return reg

# %%
# sc_X = StandardScaler()
# sc_y = StandardScaler()

# X2 = sc_X.fit_transform(X_train)
# y = sc_y.fit_transform(y_train.reshape(-1, 1))

# my_regressor = SVR(kernel='rbf', C=0.5)
# regsv = my_regressor.fit(X2, y.ravel())

# X_test2 = sc_X.transform(X_test)

# %%
sc_X = StandardScaler()
sc_y = StandardScaler()

X2 = sc_X.fit_transform(X_train)
y = sc_y.fit_transform(y_train.reshape(-1, 1))

# my_regressor = SVR(kernel='rbf', C=0.5)

regsv = fit_svreg(X2,y.ravel(),'rbf', C=1.0)
X_test2 = sc_X.transform(X_test)

# %% [markdown]
# ## Prediction Results

# %%
ypredsv = regsv.predict(X_test2)
ypredsv = ypredsv.reshape(-1, 1)
y_pred_original_scale = sc_y.inverse_transform(ypredsv)

# Calculate the RMSE in the original scale
rmsesv = np.sqrt(mean_squared_error(y_test, y_pred_original_scale))
print("RMSE:", rmsesv)

plt.figure(figsize=(12,6))
plt.plot(y_test,label ='Y Test')
plt.plot(y_pred_original_scale,label = 'Y Prediction')
plt.xlabel('BuildingNo')
plt.ylabel('TotalEnergyUsage')

plt.legend()
# Out:
# RMSE: 4288707.010583699

# %% [markdown]
# # 5.8 Regression Model Comparisons

# %%
print('LR:',rmse,'Lasso:',rmsel,'Ridge:',rmser,'OLS:',rmseS,'DT2:',rmsedr1,'DT5:',rmsedr2,'SVR:',rmsesv)
# Out:
# LR: 3748622.771232097 Lasso: 3748622.7718189317 Ridge: 3748622.821275289 OLS: 3761912.301997066 DT2: 10533201.952544754 DT5: 14061817.302792806 SVR: 4288707.010583699

# %%
rmse_values = [rmse, rmsel, rmser, rmseS, rmsedr1, rmsedr2, rmsesv]
models = ['LR', 'Lasso', 'Ridge', 'OLS', 'DT2', 'DT5', 'SVR']

plt.figure(figsize=(10, 6))

colors = ['skyblue', 'lightcoral', 'lightgreen', 'lightsalmon', 'lightblue', 'lightpink', 'lightseagreen']

for i, model in enumerate(models):
    plt.bar(model, rmse_values[i], color=colors[i])

plt.xlabel('Regression Models')
plt.ylabel('RMSE')
plt.title('RMSE for Different Regression Models')
plt.grid(axis='y', linestyle='--', alpha=0.6)

for i, value in enumerate(rmse_values):
    plt.text(i, value, f'{value:.2f}', ha='center', va='bottom')

plt.show()

# %% [markdown]
# # 6.0 Classification

# %% [markdown]
# ## Data Analysis - Scatter Plot

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import Perceptron
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.preprocessing import StandardScaler

df1 = df[ (df.GrossFloorArea_M2 <= 40000) & (df.TotalEnergy2017 <= 5000000)]
df1=df1[df1.BuildingType == 'Office Building']
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 262 entries, 3 to 1144
# Data columns (total 27 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   BuildingName                                    219 non-null    object
#  1   BuildingAddress                                 262 non-null    object
#  2   BuildingType                                    262 non-null    object
#  3   BuildingSize                                    262 non-null    object
#  4   PublicSector                                    262 non-null    object
#  5   YearObtainedTOP_CSC                             262 non-null    float64
#  6   GreenMarkYearofAward                            40 non-null     float64
#  7   GreenMarkRating                                 262 non-null    object
#  8   GreenMarkStatus                                 262 non-null    object
#  9   GrossFloorArea_M2                               262 non-null    float64
#  10  PercentageOfAirconditionedFloorArea             262 non-null    float64
#  11  AverageMonthlyBuildingOccupancyRate_percentage  262 non-null    float64
#  12  NumberOfHotelRooms                              4 non-null      float64
#  13  TypeOfAirconditioningSystem                     262 non-null    object
#  14  AgeOfNewestChiller_Airconditioner               252 non-null    float64
#  15  CentralisedAirconditioningPlantEfficiency_kWRT  53 non-null     float64
#  16  YearOfLastChillerPlantAuditHealthCheck          43 non-null     float64
#  17  PercentageUsageOfLED                            262 non-null    float64
#  18  InstallationOfSolarPV                           262 non-null    object
#  19  EUI2015_kWhM2Yr                                 262 non-null    float64
#  20  EUI2016_kWhM2Yr                                 262 non-null    float64
#  21  EUI2017_kWhM2Yr                                 262 non-null    float64
#  22  EUIPerformanceComparedToPreviousYear            262 non-null    object
#  23  Benchmarking_EUI_Quartile                       262 non-null    object
#  24  VoluntaryDisclosure                             262 non-null    object
#  25  BuildingAge                                     262 non-null    float64
#  26  TotalEnergy2017                                 262 non-null    float64
# dtypes: float64(15), object(12)
# memory usage: 57.3+ KB

# %%
sb.scatterplot(data=df1, x='TotalEnergy2017', y='GrossFloorArea_M2', hue='BuildingSize')
plt.show()

# %% [markdown]
# ## Preprocessing

# %%
columns_to_include = ['BuildingSize',
                      'GrossFloorArea_M2',
                      'TotalEnergy2017']
df1 = df1[columns_to_include].dropna()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 262 entries, 3 to 1144
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   BuildingSize       262 non-null    object
#  1   GrossFloorArea_M2  262 non-null    float64
#  2   TotalEnergy2017    262 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 8.2+ KB

# %%
y = df1['BuildingSize'].values
X = df1.drop(['BuildingSize'], axis=1).values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=2)

# %% [markdown]
# ### 6.1 Perceptron Classifier

# %%
clf = Perceptron(tol=1e-3, random_state=4)
clf.fit(X_train, y_train)

accuclf = clf.score(X_test, y_test)
print("Accuracy:", accuclf)
weightsclf= clf.coef_[0]
interceptclf = clf.intercept_[0]
# Out:
# Accuracy: 0.7777777777777778

# %% [markdown]
# ### 6.2 Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
nbclf = GaussianNB()
nbclf.fit(X_train, y_train)

accugnb = nbclf.score(X_test, y_test)
print("Accuracy:", accugnb)
# Out:
# Accuracy: 0.9629629629629629

# %%
X_try=[[10000,500000],
       [40000, 600000],
       [9000, 600000]]
y_try = nbclf.predict(X_try)
y_try
# Out:
# array(['Small', 'Large', 'Small'], dtype='<U5')

# %% [markdown]
# ### 6.3 Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dtclf = DecisionTreeClassifier(random_state=0)
dtclf.fit(X_train, y_train)

accudt = dtclf.score(X_test, y_test)
print("Accuracy:", accudt)
# Out:
# Accuracy: 1.0

# %% [markdown]
# ### 6.4 Support Vector Machine

# %%
from sklearn.pipeline import make_pipeline
from sklearn.svm import SVC
svcclf = make_pipeline(StandardScaler(), SVC(gamma='auto',C=1,kernel='rbf'))
svcclf.fit(X_train, y_train)

accusvc = svcclf.score(X_test, y_test)
print("Accuracy:", accusvc)
# Out:
# Accuracy: 1.0

# %% [markdown]
# ### 6.5 Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

logistic_reg = LogisticRegression(random_state=0)
logistic_reg.fit(X_train, y_train)

acculr = logistic_reg.score(X_test, y_test)
print("Accuracy:", acculr)

y_pred= logistic_reg.predict(X_test)
# Out:
# Accuracy: 0.5925925925925926

# %% [markdown]
# # 7.0 Classifier Model Comparison

# %%
acc_values = [accuclf,acculr,accugnb,accudt,accusvc]
models = ['Perceptron','Logistic Reg', 'Naive Bayes', 'Decision Tree', 'SVC']

plt.figure(figsize=(8, 6))

colors = ['skyblue', 'lightcoral', 'lightgreen', 'lightsalmon', 'lightblue', 'lightpink', 'lightseagreen']

for i, model in enumerate(models):
    plt.bar(model, acc_values[i], color=colors[i])

plt.xlabel('Classification Models')
plt.ylabel('Accuracy')
plt.title('Accuracy Score for Different Classification Models')
plt.grid(axis='y', linestyle='--', alpha=0.6)

for i, value in enumerate(acc_values):
    plt.text(i, value, f'{value:.2f}', ha='center', va='bottom')

plt.show()
